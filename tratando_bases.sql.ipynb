# %%
import pandas as pd

# %% [markdown]
# ## Analisando Dados de Account

# %% [markdown]
# account_account_account =pd.read_json('base_dados/accounts/01-accounts-accounts.json')
# account_details = pd.read_json('base_dados/accounts/02-accounts-details.json')
# account_balances = pd.read_json('base_dados/accounts/03-accounts-balances.json')
# account_transactions = pd.read_json('base_dados/accounts/04-accounts-transactions.json')
# accounts_overdraft_limits = pd.read_json('base_dados/accounts/05-accounts-overdraft-limits.json')

# %%
account_account_account.to_csv('account.csv',sep = ';', index=False)

# %%
account_details.to_csv('account_details.csv',sep = ';', index=False)

# %%
account_balances.to_csv('balances.csv',sep = ';' , index=False)

# %%
account_transactions.to_csv('transactions.csv',sep = ';', index=False)

# %%
accounts_overdraft_limits.to_csv('overdraft_limits.csv',sep = ';', index=False)

# %% [markdown]
# ### Análisando Dados de  credit-cards

# %%
credit_cards =pd.read_json('base_dados/credit-cards/01-credit-cards.json')
credit_cards_details = pd.read_json('base_dados/credit-cards/02-credit-cards-details.json')
credit_cards_limit = pd.read_json('base_dados/credit-cards/03-credit-cards-limits.json')
credit_cards_transactions = pd.read_json('base_dados/credit-cards/04-credit-cards-transactions.json')
credit_cards_bills = pd.read_json('base_dados/credit-cards/05-credit-cards-bills.json')
credit_cards_bills_transaction = pd.read_json('base_dados/credit-cards/06-credit-cards-bills-transactions.json')

# %%
credit_cards.to_csv('credit-cards.csv',sep = ';', index=False)
credit_cards_details.to_csv('credit_cards_details.csv',sep = ';', index=False)
credit_cards_limit.to_csv('credit_cards_limit.csv',sep = ';', index=False)
credit_cards_transactions.to_csv('credit_cards_transactions.csv',sep = ';', index=False)
credit_cards_bills.to_csv('credit_cards_bills.csv',sep = ';', index=False)
credit_cards_bills_transaction.to_csv('credit_cards_bills_transaction.csv',sep = ';', index=False)

# %%
credit_cards_bills_transaction.head()
# Out:
#                     creditCardAccountId      customerId  \
# 0  e1711229-cf83-483b-8cc1-0c8d31c81f80  362.529.240-03
# 1  e1711229-cf83-483b-8cc1-0c8d31c81f80  362.529.240-03
# 2  e1711229-cf83-483b-8cc1-0c8d31c81f80  362.529.240-03
# 3  e1711229-cf83-483b-8cc1-0c8d31c81f80  362.529.240-03
# 4  e1711229-cf83-483b-8cc1-0c8d31c81f80  362.529.240-03
#
#                          organizationId           organizationName  \
# 0  63d929c5-2a09-479e-806c-8cd073a029ab  Instituição Financeira 05
# 1  63d929c5-2a09-479e-806c-8cd073a029ab  Instituição Financeira 05
# 2  63d929c5-2a09-479e-806c-8cd073a029ab  Instituição Financeira 05
# 3  63d929c5-2a09-479e-806c-8cd073a029ab  Instituição Financeira 05
# 4  63d929c5-2a09-479e-806c-8cd073a029ab  Instituição Financeira 05
#
#                           transactionId  identificationNumber transactionName  \
# 0  193a5bb2-9e69-4266-abd0-f20ab4540e32                  3876       Decoração
# ...

# %% [markdown]
# ## Analisando Tabela Customer

# %%
financial_relation =pd.read_json('base_dados/customers/01-financial-relation.json')
personal_identification = pd.read_json('base_dados/customers/01-personal-identification.json')
personal_qualification = pd.read_json('base_dados/customers/01-personal-qualification.json')

# %%
financial_relation.to_csv('financial_relation.csv',sep = ';', index=False)
personal_identification.to_csv('personal_identification.csv',sep = ';', index=False)
personal_qualification.to_csv('personal_qualification.csv',sep = ';', index=False)

# %%
personal_identification.head()
# Out:
#                              personalId                        organizationId  \
# 0  4478301e-21e7-49e5-b4a8-bb033f41dab1  63d929c5-2a09-479e-806c-8cd073a029ab
# 1  68261048-09eb-4547-bfe5-eac4195aee9b  d3d2b0d5-903a-4f9f-b793-c139490d5ca7
# 2  a991cd22-8bf8-4ec7-8d0f-7830902a4dd9  69665991-da55-4aac-a1f2-32d23daba8fe
# 3  2a736423-2fab-4cea-ad5f-f8cb980e03d8  f4851ca0-7163-4d71-97a7-df1e999c047f
# 4  aa79da2e-4cea-4dd2-8ab3-28efc63f0117  63d929c5-2a09-479e-806c-8cd073a029ab
#
#        customerId                  brandName      civilName     socialName  \
# 0  362.529.240-03  Instituição Financeira 05  Cliente 00201  Cliente 00201
# 1  793.879.991-03  Instituição Financeira 09  Cliente 00202  Cliente 00202
# 2  927.518.283-33  Instituição Financeira 03  Cliente 00203  Cliente 00203
# 3  181.742.477-09  Instituição Financeira 07  Cliente 00204  Cliente 00204
# 4  233.845.513-06  Instituição Financeira 05  Cliente 00205  Cliente 00205
#
# ...
